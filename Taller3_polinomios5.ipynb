# %%
from sympy import init_printing as ini
ini(use_latex=True)
import sympy as sym

# %%
from sympy import laguerre 
x = sym.Symbol('x',Real=True)
n=0

for n in range(1,21,1):
  display(laguerre(n,x))
# Out:
# 1 - x
#  2
# x
# ── - 2⋅x + 1
# 2
#    3      2
#   x    3⋅x
# - ── + ──── - 3⋅x + 1
#   6     2
#  4      3
# x    2⋅x       2
# ── - ──── + 3⋅x  - 4⋅x + 1
# 24    3
#     5      4      3
#    x    5⋅x    5⋅x       2
# - ─── + ──── - ──── + 5⋅x  - 5⋅x + 1
#   120    24     3
#   6    5      4       3       2
#  x    x    5⋅x    10⋅x    15⋅x
# ─── - ── + ──── - ───── + ───── - 6⋅x + 1
# 720   20    8       3       2
#     7       6      5       4       3       2
#    x     7⋅x    7⋅x    35⋅x    35⋅x    21⋅x
# - ──── + ──── - ──── + ───── - ───── + ───── - 7⋅x + 1
#   5040   720     40      24      6       2
#    8      7      6      5       4       3
#   x      x    7⋅x    7⋅x    35⋅x    28⋅x        2
# ───── - ─── + ──── - ──── + ───── - ───── + 14⋅x  - 8⋅x + 1
# 40320   630   180     15      12      3
#      9       8      7      6       5       4
#     x       x      x    7⋅x    21⋅x    21⋅x        3       2
# - ────── + ──── - ─── + ──── - ───── + ───── - 14⋅x  + 18⋅x  - 9⋅x + 1
# ...
