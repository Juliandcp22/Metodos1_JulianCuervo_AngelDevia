# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import math

# %%
N = 10*4
k = np.linspace(0,30,N)
x = []
M = 2**48
A = 0
B = 1
xo = 25
r = np.random.randint(N)


tot = 0
C_k = []


for i in range(N):
  b = np.random.randint(N)/M 
  x.append(b)

for i in range(N):    
    i_k = (x[i]+k[i])
    xi_k = x[i]*i_k
    tot = tot + xi_k
    C_k.append((tot/(N)))

my = np.corrcoef(k)

plt.plot(k, C_k)
plt.plot(k,x)
print(C_k)
print(x)
# Out:
# [3.1554436208840474e-31, 1.4347497549003418e-15, 3.6210350957007304e-15, 1.1204712371602233e-14, 1.2844426377202475e-14, 1.8993353898203444e-14, 2.842170943040494e-14, 3.0812959021905286e-14, 4.010467172030669e-14, 4.3179135480807134e-14, 4.727842049480772e-14, 6.681834572821069e-14, 7.173748774501139e-14, 8.328380720111307e-14, 8.710980654751361e-14, 1.0043248284301555e-13, 1.1682962289901794e-13, 1.5980379412912444e-13, 1.794803621963273e-13, 2.1842356982933308e-13, 2.525842782793381e-13, 2.6406227631853977e-13, 3.076513403007462e-13, 3.1550830324424726e-13, 3.7945714946265683e-13, 3.999535745326598e-13, 4.3903342499946545e-13, 4.999078074573744e-13, 5.209508038625774e-13, 5.823717576556864e-13, 5.86471042669687e-13, 6.373021768432943e-13, 6.63537600932898e-13, 7.289211969062076e-13, 7.684109758744131e-13, 8.305834652534221e-13, 8.502600333206248e-13, 8.907063121254306e-13, 9.711889412336423e-13, 1.0617831400430555e-12]
# ...
